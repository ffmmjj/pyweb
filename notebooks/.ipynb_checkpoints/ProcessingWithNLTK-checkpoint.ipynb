# %% [markdown]
# # Processing a large email inbox with NLTK and ScikitLearn

# %% [markdown]
# ### 1. Decode an email message using base64

# %%
import base64

# %%
body = 'PGh0bWwgeG1sbnM9Imh0dHA6Ly93d3cudzMub3JnLzE5OTkveGh0bWwiIHhtbDpsYW5nPSJwdC1i \
ciIKICAgICAgbGFuZz0icHQtYnIiPgoKICAKICA8aGVhZD4KICAgIDxtZXRhIGNvbnRlbnQ9InRl \
eHQvaHRtbDtjaGFyc2V0PXV0Zi04IiBodHRwLWVxdWl2PSJDb250ZW50LVR5cGUiPgogIDwvaGVh \
ZD4KCiAgPGJvZHk+CiAgICA8ZGl2IHN0eWxlPSJtYXJnaW46IDEwcHg7Ij4gICAgICAgICAgICAK \
ICAgICAgPGxhYmVsIHN0eWxlPSJmb250LXdlaWdodDogYm9sZDsiPk5vbWUgZG8gcmVtZXRlbnRl \
OjwvbGFiZWw+CiAgICAgIDxzcGFuPlZJUkdJTklBIENPTkRPUkkgQ0hPUVVFPC9zcGFuPiAgICAK \
ICAgIDwvZGl2PgogICAgPGRpdiBzdHlsZT0ibWFyZ2luOiAxMHB4OyI+ICAgICAgICAgICAgCiAg \
ICAgIDxsYWJlbCBzdHlsZT0iZm9udC13ZWlnaHQ6IGJvbGQ7Ij5FLW1haWwgZG8gcmVtZXRlbnRl \
OjwvbGFiZWw+CiAgICAgIDxzcGFuPm1pX2FuZ2VsX2VzcGVqb0Bob3RtYWlsLmNvbTwvc3Bhbj4g \
ICAgCiAgICA8L2Rpdj4KICAgIDxkaXYgc3R5bGU9Im1hcmdpbjogMTBweDsiPiAgICAgICAgICAg \
IAogICAgICA8bGFiZWwgc3R5bGU9ImZvbnQtd2VpZ2h0OiBib2xkOyI+QXNzdW50bzo8L2xhYmVs \
PgogICAgICA8c3Bhbj5FdSBxdWVybyBwYXJ0aWNpcGFyIGRlIE8gRXhhbWUgTmFjaW9uYWwgZGUg \
UmV2YWxpZGHDp8OjbyBkZSBEaXBsb21hcyBNw6lkaWNvcyAyMDE0PC9zcGFuPiAgICAKICAgIDwv \
ZGl2PgogICAgPGRpdiBzdHlsZT0ibWFyZ2luOiAxMHB4OyI+ICAgICAgICAgICAgCiAgICAgIDxs \
YWJlbCBzdHlsZT0iZm9udC13ZWlnaHQ6IGJvbGQ7Ij5UaXBvOjwvbGFiZWw+CiAgICAgIDxzcGFu \
Pk91dHJvPC9zcGFuPgogICAgPC9kaXY+ICAgICAKICAgIDxkaXYgc3R5bGU9Im1hcmdpbjogMTBw \
eDsiPiAgICAgICAgICAgIAogICAgICA8bGFiZWwgc3R5bGU9ImZvbnQtd2VpZ2h0OiBib2xkOyI+ \
ZGF0YSBkZSBlbnZpbzo8L2xhYmVsPgogICAgICA8c3Bhbj4yNC8wNi8yMDE0IDAxOjE5OjMzPC9z \
cGFuPiAgICAKICAgIDwvZGl2PgogICAgPGRpdiBzdHlsZT0ibWFyZ2luOiAxMHB4OyI+ICAgICAg \
ICAgICAgCiAgICAgIDxsYWJlbCBzdHlsZT0iZm9udC13ZWlnaHQ6IGJvbGQ7Ij5SZXNwb25kaWRh \
OjwvbGFiZWw+CiAgICAgIDxzcGFuPlNpbTwvc3Bhbj4KICAgIDwvZGl2PgogICAgPGRpdiBzdHls \
ZT0ibWFyZ2luOiAxMHB4OyI+ICAgICAgICAgICAgCiAgICAgIDxsYWJlbCBzdHlsZT0iZm9udC13 \
ZWlnaHQ6IGJvbGQ7Ij5NZW5zYWdlbSBFeHRlcm5hOjwvbGFiZWw+CiAgICAgIDxzcGFuPlNpbTwv \
c3Bhbj4KICAgIDwvZGl2PgogICAgPGRpdiBzdHlsZT0ibWFyZ2luOiAxMHB4OyI+ICAgICAgICAg \
ICAgCiAgICAgIDxsYWJlbCBzdHlsZT0iZm9udC13ZWlnaHQ6IGJvbGQ7Ij5NZW5zYWdlbTo8L2xh \
YmVsPjxiciAvPjxiciAvPgogICAgICA8ZGl2PkJvYSBub2l0ZSwgcG9yIGZhdm9yIGV1IHF1ZXJv \
IHBhcnRpY2lwYXIgZGUgTyBFeGFtZSBOYWNpb25hbCBkZSBSZXZhbGlkYcOnw6NvIGRlIERpcGxv \
bWFzIE3DqWRpY29zIEV4cGVkaWRvcyBwb3IgSW5zdGl0dWnDp8O1ZXMgZGUgRWR1Y2HDp8OjbyBT \
dXBlcmlvciBFc3RyYW5nZWlyYXMg4oCTIFJFVkFMSURBIDIwMTQsIG1haXMgbsOjbyBwb3NzbyBm \
YXplciBtaW5oYSBpbnNjcmnDp8OjbyBwb3IgcXVlIG5vIGFubyBwYXNzYWRvIHF1aXMgZmF6ZXIg \
bWluaGEgaW5zY3Jpw6fDo28gcGVybyBmb2kgdGFyZGUgZGVtYWlzIGUgbyBjYWRhc3RybyBxdWUg \
Zml6IGZvaSBjb20gdW0gZS1tYWlsIHF1ZSBwZXJkaSAocGVyZGkgYSBjb250YSllIG7Do28gbGVt \
YnJvIGEgc2VuaGEsIFBPUkZBVk9SIENPTU8gUE9TU08gRkFaRVIgUEFSQS1NRSBDQURBU1RSQVIg \
Tk9WQU1FTlRFIENPTSBPVVRSTyBFLU1BSUwsIFBPUiBGQVZPUiBNRSBBSlVERSwgRVUgUVVFUk8g \
TVVJVE8gTUVTTU8gUEFSVElDSVBBUiBEQSBQUk9WQS4gZXUgcGXDp28gc3VhIGFqdWRhIGUgZ3Jh \
dGEgYW50ZWNpcGFkYW1lbnRlIHBlbGEgc3VhIGFqdWRhIFBPUkZBVk9SLjxici8+T3UgcG9yIGZh \
dm9yIG1lIGRpZ2EgY29tbyBldSBwb3NzbyBmYWxhciBjb20gdm9jw6pzLjxici8+TWV1IGUtbWFp \
bCBhdHVhbCBtaV9hbmdlbF9lc3Blam9AaG90bWFpbC5jb208L2Rpdj4gICAgCiAgICA8L2Rpdj4K \
ICA8L2JvZHk+CjwvaHRtbD4K'
email_body = base64.b64decode(body)
print email_body
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="pt-br"
#       lang="pt-br">
#
#
#   <head>
#     <meta content="text/html;charset=utf-8" http-equiv="Content-Type">
#   </head>
#
#   <body>
#     <div style="margin: 10px;">
#       <label style="font-weight: bold;">Nome do remetente:</label>
#       <span>VIRGINIA CONDORI CHOQUE</span>
#     </div>
#     <div style="margin: 10px;">
#       <label style="font-weight: bold;">E-mail do remetente:</label>
#       <span>mi_angel_espejo@hotmail.com</span>
#     </div>
#     <div style="margin: 10px;">
#       <label style="font-weight: bold;">Assunto:</label>
#       <span>Eu quero participar de O Exame Nacional de Revalidação de Diplomas Médicos 2014</span>
#     </div>
#     <div style="margin: 10px;">
#       <label style="font-weight: bold;">Tipo:</label>
#       <span>Outro</span>
#     </div>
#     <div style="margin: 10px;">
#       <label style="font-weight: bold;">data de envio:</label>
#       <span>24/06/2014 01:19:33</span>
#     </div>
#     <div style="margin: 10px;">
#       <label style="font-weight: bold;">Respondida:</label>
#       <span>Sim</span>
#     </div>
#     <div style="margin: 10px;">
#       <label style="font-weight: bold;">Mensagem Externa:</label>
#       <span>Sim</span>
#     </div>
#     <div style="margin: 10px;">
#       <label style="font-weight: bold;">Mensagem:</label><br /><br />
#       <div>Boa noite, por favor eu quero participar de O Exame Nacional de Revalidação de Diplomas Médicos Expedidos por Instituições de Educação Superior Estrangeiras – REVALIDA 2014, mais não posso fazer minha inscrição por que no ano passado quis fazer minha inscrição pero foi tarde demais e o cadastro que fiz foi com um e-mail que perdi (perdi a conta)e não lembro a senha, PORFAVOR COMO POSSO FAZER PARA-ME CADASTRAR NOVAMENTE COM OUTRO E-MAIL, POR FAVOR ME AJUDE, EU QUERO MUITO MESMO PARTICIPAR DA PROVA. eu peço sua ajuda e grata antecipadamente pela sua ajuda PORFAVOR.<br/>Ou por favor me diga como eu posso falar com vocês.<br/>Meu e-mail atual mi_angel_espejo@hotmail.com</div>
#     </div>
#   </body>
# </html>

# %% [markdown]
# ### 2. Parse and extract relevant features from email body

# %%
from pyquery import PyQuery
import unicodedata
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-617910fc7411> in <module>()
# ----> 1 from pyquery import PyQuery
#       2 import unicodedata
#
# ImportError: No module named pyquery

# %%
def unicode_normalize(text):
    return unicodedata.normalize('NFKD', unicode(text)).encode('ascii','ignore')

# %%
def parse_email(email_body):
    email_parser = PyQuery(email_body)
    email_fields = [unicode_normalize(span.text) for span in email_parser('div>span')]
    
    feature_names = ['remetente', 'email', 'assunto', 'tipo', 'data_envio', 'respondida?', 'mensagem_externa?']
    features = dict(zip(feature_names, email_fields))
    
    features['mensagem'] = unicode_normalize(email_parser('div>div').text()).lower()
    return features

# %%
email_features = parse_email(email_body)
print email_features
# Out:
# {'tipo': 'Outro', 'assunto': 'Eu quero participar de O Exame Nacional de Revalidacao de Diplomas Medicos 2014', 'respondida?': 'Sim', 'data_envio': '24/06/2014 01:19:33', 'mensagem': 'boa noite, por favor eu quero participar de o exame nacional de revalidacao de diplomas medicos expedidos por instituicoes de educacao superior estrangeiras  revalida 2014, mais nao posso fazer minha inscricao por que no ano passado quis fazer minha inscricao pero foi tarde demais e o cadastro que fiz foi com um e-mail que perdi (perdi a conta)e nao lembro a senha, porfavor como posso fazer para-me cadastrar novamente com outro e-mail, por favor me ajude, eu quero muito mesmo participar da prova. eu peco sua ajuda e grata antecipadamente pela sua ajuda porfavor. ou por favor me diga como eu posso falar com voces. meu e-mail atual mi_angel_espejo@hotmail.com', 'mensagem_externa?': 'Sim', 'email': 'mi_angel_espejo@hotmail.com', 'remetente': 'VIRGINIA CONDORI CHOQUE'}

# %% [markdown]
# ### 3. Open messages file

# %%
messages = []
input_file = open('../../INBOX.Arquivo Remoto.mbox')
line = input_file.readline()
while line:
    if 'X-Proofpoint-Virus-Version' in line: 
        content = ''
        input_file.readline()
        line = input_file.readline()
        line = ''
        while line != '\n':
            line = input_file.readline()
            content += line
        messages.append(content)
    line = input_file.readline()

# %%
# IN PROGRESS, DO NOT RUN
import mailbox
import email
import json

MBOX = '../../INBOX.Arquivo Remoto.mbox'
mbox = mailbox.UnixMailbox(open(MBOX, 'rb'), email.message_from_file)

def objectify_message(msg):
    o_msg = dict([ (k, v) for (k,v) in msg.items() ])
    
    part = [p for p in msg.walk()][0]
    o_msg['contentType'] = part.get_content_type()
    o_msg['content'] = part.get_payload()
    
    return o_msg

messages = []
while 1:
    msg = mbox.next()
    if msg is None: break
    messages.append(objectify_message(msg))
    
print json.dumps(messages, indent=1)
# Out:
# []

# %%
len(messages)
# Out:
# 33941

# %%
messages[3]
# Out:
# '\n\n'

# %%
emails = []
for message in messages:
    try:
        decoded_message = base64.b64decode(message)
        emails.append(parse_email(decoded_message))
    except:
        pass

# %%
len(emails)
# Out:
# 33299

# %%
emails[3]
# Out:
# {'assunto': 'Rede Publica',
#  'data_envio': '30/07/2014 22:57:47',
#  'email': 'nubia_milanezi@hotmail.com',
#  'mensagem': 'ola, boa noite! escrevo como estudante, fiz todo o ensino na rede publica e com muito esforco tirei o melhor proveito. ainda existem excelente professores sim, aqueles que tem vontade de ensinar e sao por esses professores que me empenhei para ter uma boa pontuacao no enem e conseguir uma bolsa parcial para estudar em uma otima faculdade que estou hoje (esamc). atualmente estou finalizando meu curso em publicidade e propaganda e almejo um intercambio. trabalho desde os meus 13 anos,(como minha mae dizia nao era pelo valor mas sim pela responsabilidade e valorizacao no trabalho. e assim eu cresci com a minha mae e minha irma me ajudando. hoje venha em nome de todos os estudantes pedir uma ajuda, tenho esse sonho de estudar ingles em outro pais e me especializar na minha area, mas mesmo com meu salario inteiro e a ajuda da minha mae isso nao e possivel. com toda a confianca que voce tem na educacao no brasil peco sua ajuda, qualquer que seja sera muito bem-vinda. nubia milanezi',
#  'mensagem_externa?': 'Sim',
#  'remetente': 'Nubia Milanezi',
#  'respondida?': 'Nao',
#  'tipo': 'Outro'}

# %% [markdown]
# ### 4.  TF-IDF and KMeans Clustering

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.cluster import KMeans

import nltk
import string

from nltk.corpus import stopwords
from nltk.stem.snowball import *

from collections import Counter

# %% [markdown]
# #### Stopwords

# %%
stopwords.words('portuguese')
# Out:
# [u'de',
#  u'a',
#  u'o',
#  u'que',
#  u'e',
#  u'do',
#  u'da',
#  u'em',
#  u'um',
#  u'para',
#  u'com',
#  u'n\xe3o',
#  u'uma',
#  u'os',
#  u'no',
#  u'se',
#  u'na',
#  u'por',
#  u'mais',
#  u'as',
#  u'dos',
#  u'como',
#  u'mas',
#  u'ao',
#  u'ele',
#  u'das',
#  u'\xe0',
#  u'seu',
#  u'sua',
#  u'ou',
#  u'quando',
#  u'muito',
#  u'nos',
#  u'j\xe1',
#  u'eu',
#  u'tamb\xe9m',
#  u's\xf3',
#  u'pelo',
#  u'pela',
#  u'at\xe9',
#  u'isso',
#  u'ela',
#  u'entre',
#  u'depois',
#  u'sem',
#  u'mesmo',
#  u'aos',
#  u'seus',
#  u'quem',
#  u'nas',
#  u'me',
#  u'esse',
#  u'eles',
#  u'voc\xea',
#  u'essa',
#  u'num',
#  u'nem',
#  u'suas',
#  u'meu',
#  u'\xe0s',
#  u'minha',
#  u'numa',
#  u'pelos',
#  u'elas',
#  u'qual',
#  u'n\xf3s',
#  u'lhe',
#  u'deles',
#  u'essas',
#  u'esses',
#  u'pelas',
#  u'este',
#  u'dele',
#  u'tu',
#  u'te',
#  u'voc\xeas',
#  u'vos',
#  u'lhes',
#  u'meus',
#  u'minhas',
#  u'teu',
#  u'tua',
#  u'teus',
#  u'tuas',
#  u'nosso',
#  u'nossa',
#  u'nossos',
#  u'nossas',
#  u'dela',
#  u'delas',
#  u'esta',
#  u'estes',
#  u'estas',
#  u'aquele',
#  u'aquela',
#  u'aqueles',
#  u'aquelas',
#  u'isto',
#  u'aquilo',
#  u'estou',
#  u'est\xe1',
#  u'estamos',
#  u'est\xe3o',
#  u'estive',
#  u'esteve',
#  u'estivemos',
#  u'estiveram',
#  u'estava',
#  u'est\xe1vamos',
#  u'estavam',
#  u'estivera',
#  u'estiv\xe9ramos',
#  u'esteja',
#  u'estejamos',
#  u'estejam',
#  u'estivesse',
#  u'estiv\xe9ssemos',
#  u'estivessem',
#  u'estiver',
#  u'estivermos',
#  u'estiverem',
#  u'hei',
#  u'h\xe1',
#  u'havemos',
#  u'h\xe3o',
#  u'houve',
#  u'houvemos',
#  u'houveram',
#  u'houvera',
#  u'houv\xe9ramos',
#  u'haja',
#  u'hajamos',
#  u'hajam',
#  u'houvesse',
#  u'houv\xe9ssemos',
#  u'houvessem',
#  u'houver',
#  u'houvermos',
#  u'houverem',
#  u'houverei',
#  u'houver\xe1',
#  u'houveremos',
#  u'houver\xe3o',
#  u'houveria',
#  u'houver\xedamos',
#  u'houveriam',
#  u'sou',
#  u'somos',
#  u's\xe3o',
#  u'era',
#  u'\xe9ramos',
#  u'eram',
#  u'fui',
#  u'foi',
#  u'fomos',
#  u'foram',
#  u'fora',
#  u'f\xf4ramos',
#  u'seja',
#  u'sejamos',
#  u'sejam',
#  u'fosse',
#  u'f\xf4ssemos',
#  u'fossem',
#  u'for',
#  u'formos',
#  u'forem',
#  u'serei',
#  u'ser\xe1',
#  u'seremos',
#  u'ser\xe3o',
#  u'seria',
#  u'ser\xedamos',
#  u'seriam',
#  u'tenho',
#  u'tem',
#  u'temos',
#  u't\xe9m',
#  u'tinha',
#  u't\xednhamos',
#  u'tinham',
#  u'tive',
#  u'teve',
#  u'tivemos',
#  u'tiveram',
#  u'tivera',
#  u'tiv\xe9ramos',
#  u'tenha',
#  u'tenhamos',
#  u'tenham',
#  u'tivesse',
#  u'tiv\xe9ssemos',
#  u'tivessem',
#  u'tiver',
#  u'tivermos',
#  u'tiverem',
#  u'terei',
#  u'ter\xe1',
#  u'teremos',
#  u'ter\xe3o',
#  u'teria',
#  u'ter\xedamos',
#  u'teriam']

# %%
stopwords_extended = ['nao', 'ja', 'pois', 'pra', 'sobre', 'deste', 'ta', 'bom', 'obrigado', 'obrigada']
stopwords_extended.extend(['gostaria', 'saber', 'fazer', 'boa', 'ate'])
stopwords_extended.extend(stopwords.words('portuguese'))

# %% [markdown]
# #### Tokenizing

# %%
def get_tokens(text):
    lowers = text.lower()
    no_punctuation = lowers.translate(None, string.punctuation)
    tokens = nltk.word_tokenize(no_punctuation)
    return tokens

tokens = get_tokens(emails[210]['mensagem'])
filtered = [w for w in tokens if not w in stopwords_extended]
count = Counter(filtered)
print count.most_common(100)
# Out:
# [('consigo', 2), ('suspender', 1), ('46669003811', 1), ('erro', 1), ('senha', 1), ('faculdade', 1), ('tirei', 1), ('logar', 1), ('vou', 1), ('exibe', 1), ('tranquei', 1), ('contrato', 1), ('cadastrado', 1), ('tentando', 1), ('suspencao', 1), ('novo', 1), ('posso', 1), ('aqui', 1), ('nova', 1), ('permanesse', 1), ('20140000416031', 1), ('todas', 1), ('dias', 1), ('pedir', 1), ('protocolo', 1), ('segui', 1), ('menssagem', 1), ('cadastrar', 1), ('conta', 1), ('ha', 1), ('ultimo', 1), ('atendimento', 1), ('semestre', 1), ('printscreen', 1), ('570501892', 1), ('anexar', 1), ('resolveu', 1), ('temporariamente', 1), ('fies', 1), ('0800', 1), ('orientacoes', 1), ('cpf', 1), ('email', 1), ('alguns', 1), ('orientado', 1)]

# %% [markdown]
# #### Stemming

# %%
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

stemmer = SnowballStemmer('portuguese')
stemmed = stem_tokens(filtered[:1000], stemmer)
count = Counter(stemmed)
print count.most_common(20)
# Out:
# [(u'dia', 11), (u'sit', 11), (u'email', 11), (u'faculdad', 10), (u'ajud', 10), (u'estud', 9), (u'curs', 9), (u'tard', 9), (u'precis', 7), (u'quer', 7), (u'cadastr', 7), (u'acess', 7), (u'fac', 6), (u'inform', 6), (u'tod', 6), (u'encontr', 6), (u'envi', 6), (u'inscrica', 6), (u'contat', 6), (u'are', 6)]

# %%
texto = ' '.join([d['mensagem'] for d in emails])
tokens = get_tokens(texto)
filtered = [w for w in tokens if not w in stopwords_extended]
count = Counter(filtered)
print count.most_common(20)
# Out:
# [('curso', 7504), ('dia', 6629), ('preciso', 4872), ('faculdade', 4785), ('inscricao', 4342), ('mec', 4272), ('fies', 3772), ('consigo', 3732), ('aguardo', 3721), ('faco', 3639), ('desde', 3620), ('site', 3549), ('tarde', 3477), ('favor', 3462), ('posso', 3081), ('ensino', 2885), ('fiz', 2813), ('resposta', 2750), ('escola', 2745), ('ano', 2693)]

# %% [markdown]
# #### Pre-processing messages

# %%
def preparar_mensagem(text):
    tokens = get_tokens(text)
    filtered = [w for w in tokens if not w in stopwords_extended]
    stemmer = SnowballStemmer('portuguese')
    stemmed = stem_tokens(filtered, stemmer)
    return ' '.join(stemmed)

# %%
import random

preparar_mensagem(random.choice(emails)['mensagem'])
# Out:
# u'bibliotec escol estadual receb acervosm exist possibil recebel nov crianc busc muit livr bibliotec quantidad livr sid pouc demand alunodesd agradec atenca'

# %%
mensagens_limpas = [preparar_mensagem(d['mensagem']) for d in emails]

# %% [markdown]
# #### Running TF-IDF

# %%
vectorizer = TfidfVectorizer(max_df=0.5, max_features=10000,
                                 min_df=2, stop_words=stopwords_extended,
                                 use_idf=True)
X = vectorizer.fit_transform(mensagens_limpas)

# %% [markdown]
# #### Clustering

# %%
number_of_clusters = 10

km = KMeans(n_clusters=number_of_clusters, init='k-means++', max_iter=100, n_init=1,verbose=False)
km.fit(X)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=100, n_clusters=10, n_init=1,
#     n_jobs=1, precompute_distances=True, random_state=None, tol=0.0001,
#     verbose=False)

# %%
print("Top terms per cluster:")
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(number_of_clusters):
    print("Cluster %d:" % i)
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind])
    print
# Out:
# Top terms per cluster:
# Cluster 0:
#  precis
#  dia
#  receb
#  quer
#  cadastr
#  sit
#  poss
#  consig
#  solicit
#  trabalh
#
# Cluster 1:
#  fac
#  cadastr
#  consegu
#  precis
#  tard
#  quer
#  obter
#  via
#  ola
#  dia
#
# Cluster 2:
#  curs
#  mec
#  reconhec
#  faculdad
#  tecnic
#  graduaca
#  instituica
#  distanc
#  pos
#  quer
#
# Cluster 3:
#  inscrica
#  enem
#  pagament
#  efetu
#  consig
#  dia
#  sit
#  fiz
#  tent
#  consegu
#
# Cluster 4:
#  escol
#  faculdad
#  alun
#  estud
#  diplom
#  curs
#  univers
#  professor
#  dia
#  pod
#
# Cluster 5:
#  fies
#  adit
#  banc
#  precis
#  faculdad
#  consig
#  semestr
#  contrat
#  financ
#  consegu
#
# Cluster 6:
#  senh
#  acess
#  cadastr
#  email
#  consig
#  cpf
#  nov
#  precis
#  recuper
#  consegu
#
# Cluster 7:
#  ensin
#  medi
#  certific
#  escol
#  conclu
#  conclusa
#  enem
#  ano
#  fundamental
#  mec
#
# Cluster 8:
#  vag
#  empreg
#  curs
#  remanescent
#  inscrica
#  consig
#  proun
#  consegu
#  sisutec
#  concorr
#
# Cluster 9:
#  benefici
#  numer
#  receb
#  precis
#  cpf
#  inss
#  pis
#  extrat
#  quer
#  poss

# %%
Counter(km.predict(X))
# Out:
# Counter({0: 14455, 4: 4998, 2: 3231, 5: 2516, 3: 2028, 1: 1925, 6: 1386, 7: 1080, 9: 1069, 8: 611})

# %%
indices = [ind for ind, x in enumerate(km.predict(X)) if x == 4]

# %%
[emails[i]['assunto'] for i in indices]
# Out:
# ['Rede Publica',
#  'material didatico para autista',
#  'FACULDADE',
#  'Descredenciamento da Faculdade Gama Filho.',
#  'DECLARACAO ESCOLAR',
#  'Reclamacao colegio particular.',
#  'escola de tempo integral para regiao de sao mateus sp',
#  'Reconhecimento de diplomas de faculdades no exterior',
#  'Duvidas sobre Gama Filho',
#  'Lei que regulamenta aprovacao de aluno laudado',
#  'NOME DO CPF DA MINHA FILHA DADO ENTRADA NA ESCOLA VEIO ERRADO',
#  'Recuperacao de Documentos ',
#  'Laboratorio de informatica',
#  'Livros didaticos - faltou na distribuicao - Ensino Fundamenmtal anos finais',
#  'Chancelar historico escolar en Sao Paulo',
#  'Insatisfacao com Professor.',
#  'denuncia de funcionamento de curso',
#  'DIPLOMA POS GRADUACAO',
#  'ESTOU QUERENDO IMPRESSO OS NOVOS LIVROS QUE SUBISTITUIU O RCNEI DA EDUCACAO INFANTIL',
#  'Reconhecimento de Diploma Universitario',
#  'Reclamacao de cursos ofertados pelo SENAI',
#  'Prouni',
#  'Ifrn ',
#  'Historico validado',
#  'se confiavel faculdade unamericanas ',
#  'Sala de aula',
#  'Revalidar o curso no Brasil ',
#  'escolas autorizadas',
#  'Diploma',
#  'Cobranca indevida pela Universidade e coacao para nao reclamar',
#  'Estudantes Municipio de Nilopolis',
#  'Minha filha precisa prosseguir com os estudos!!!',
#  'Emissao de diploma Universidade Gama Filho',
#  'Cancelamento e transferencia para outra faculdade',
#  'Reclamacao-Universidade Norte do Parana - Unopar',
#  'orientacao referente a problemas com instituicao',
#  'prorrogacao de ferias escolares de autistas',
#  'copa',
#  'carimbo em historico escolar ',
#  'Pedido de informacao',
#  'telefone fixo',
#  'IDEB',
#  'faculdade Alvorada',
#  'escola reconheciads pelo MEC',
#  'informativa',
#  'dificuldade de aprendizagem e acompanhamento.',
#  'ENEM 2014',
#  'Trabalho em grupo',
#  'preciso do meu historico escolar da universidade gama filho. onde consigo pegar?',
#  'ENADE',
#  'Escola para ser fechada',
#  ' reclamacao iftm',
#  'TRASNFERENCIA EXTERNA',
#  'Universidade Norte do Parana',
#  'Faculdade unopar....intercalando periodos',
#  ' reclamacao iftm',
#  'enem',
#  'Pacto Nacional Pelo Fortalecimento do Ensino Medio',
#  'duvida ',
#  'Nao entendo...',
#  'telefone fixo',
#  'nao tem vaga para tec de Edificacao no RN/ NATAL',
#  'Confirmacao de diploma',
#  'UNIESP PAGA',
#  'Tablet',
#  'Documentos',
#  'certificacao ',
#  'confirmacao de presenca errado',
#  'inscricao',
#  'PLANILHA DO LIVRO DIDATICO',
#  'Curso pronatec',
#  'Sigiloso/Denuncia ',
#  'Envio documentos por instituicao descredenciada',
#  'direitos da merendeira',
#  'Inscricao para Lecionar',
#  'Situacao de ensino da faculdade',
#  'Explicacoes ',
#  'RECLAMACAO DENUNCIA CENTRO DE POS GRADUACAO UBERLANDIA/MG',
#  'Denuncia de irregularidade em lista de material escolar',
#  'estou encaminhando meu e mais a pedido da embaixada de Boston(brasilia) para maiores esclarecimento.',
#  'Problemas no Sistec',
#  'certificado de curso',
#  'tirar duvida',
#  'informacao',
#  'Cursos a distancia',
#  'Historico escolar',
#  'legalizacao de documentos ',
#  'Nao entrega de  diploma de curso superior',
#  'Bolsas remanescentes ',
#  'Sobre o SBA ',
#  'DOCUMENTOS QUE FORAM PARA SEREM CARIMBADOS',
#  'Denuncia',
#  'Duvida ',
#  'documentacao de estudante estrangeiro',
#  'numero de alunos por Sala de Aula',
#  'Denuncia ao IBMEC quanto a modalidade a distancia (EAD) e presencial ao MBA executivo em Projetos.',
#  'matricula',
#  'RECLAMACAO',
#  'COBRANCA POR ESTAGIO',
#  'PDDE',
#  'duvida sobre solicitacao de diploma',
#  'Bolsas ',
#  'DIPLOMACAO UNIVERCIDADE DA CIDADE RJ',
#  'Queixa de Inclusao Social - Verba Ma Administrada',
#  'Duvidas a respeito de avaliacao de estagio',
#  'transferencia',
#  'Centro Universitario da Cidade',
#  'Duvidas de autenticidade de certificados de conclusao do encino medio',
#  'Processo de Selecao de Mestrado Metodos Numericos Aplicados a Engenharia',
#  'estudar',
#  'Diploma',
#  'denuncia',
#  'Bolsa integral',
#  'Constrangiemnto devido a Conta Bancaria Bloqueada',
#  'diploma',
#  'Validacao de Diploma',
#  'tranferia pronatec',
#  'Bilhete unico estudante',
#  'Certificado de Conclusao de Curso',
#  'DENUNCIA',
#  'Pronatec',
#  'TRANSFERENCIA ASSISTIDA',
#  'Historico escolar',
#  'dados do municipio de olinda',
#  'duvida',
#  'Pronatec',
#  'denuncia faculdade ',
#  'fechamento colegio brasileiro de estudos sistemicos ( CBES)',
#  'Certificado de conclusao de pos graduacao nao confeccionado',
#  'Comprovante de escolaridade',
#  'SELO MEC',
#  'Reclamacao\t\t Assunto:\tperdi 1 semestre da faculdade porq nao encontram meu diploma encceja de 2013\t ',
#  'Denuncia',
#  'Provas de recuperacao',
#  'Reclamacao contra a Faculdade Mauricio de Nassau',
#  'Historico Escolar Universidade Sao Marcos',
#  'Pos Graduacao ead',
#  'reclamacao por cobranca ',
#  'problemas no ensino superior',
#  'Diploma nao entregue pela faculdade Pitagoras BH.MG',
#  'DENUNCIA',
#  'Resposta de recurso Ciencias Sem Fronteiras Canada Graduacao sanduiche',
#  'vinculo com a faculdade',
#  'gostaria de ser professor',
#  'DENUNCIA ',
#  'documentacao escolra',
#  'LIVROS DIDATICOS ',
#  'Troca de sala e misturar 4 cursos diferentes em uma unica sala',
#  'problemas com a faculdade anhanguera',
#  'reclamacao',
#  'UGF',
#  'enem',
#  'cancelamento de curso',
#  'componente curricular',
#  'duvida',
#  'naahs de salvador/ba',
#  'Duvidas sobre ferias',
#  'Instrumentos para estagio',
#  'Revalidacao de diploma e trabalho no exterior',
#  'Aluno cego sem nenhum tipo de assistencia',
#  'Pos Graduacao',
#  'ENADE',
#  'Faculdade Privada nao aceita Atestado medico ',
#  'instalacao de computador na sala multifuncional',
#  'Pegar Diploma - Faculdade sumio ',
#  'PROBLEMAS  E DESCASO COM ALUNO.',
#  'reclamacao faculdade',
#  'Programa mais educacao',
#  'Gostaria de saber',
#  'Revolta',
#  'Fechamento do Censo Escolar',
#  'Documentos para transferencia matricula-Gama Filho',
#  'DUVIDAS SOBRE AJUDA DE CUSTO - SISU',
#  'AUTORIZACAO MEC',
#  'Denuncia sobre faculdade',
#  'REGISTRO DE FACULDADES',
#  'Uma duvida',
#  'solicitacao da suspensao semestre 2/2013',
#  'Reclamacao de uma Universidade',
#  'bousa estudo para estuda muito',
#  'DIPLOMA',
#  'projeto teatro',
#  'Faculdade que Fechou',
#  'faculdade Uniesp Centro velho',
#  'Programa Professores Visitantes',
#  'DIPLOMA ',
#  'Fale Conosco MEC - PDDE',
#  'Irregularidade na bolsa',
#  'Vestibular Unievangelica - Anapolis - Goias - Arquitetura e Urbanismo',
#  'Denuncia',
#  'Diploma da Universidade Gama Filho - RJ',
#  'transferencia de fies',
#  'Cancelamento da matricula do SISUTEC',
#  'faltas na faculdade',
#  'cadastro para TOEFL',
#  'informacao sobre diploma a nivel superior',
#  'HISTORICO ESCOLAR  CURSO DE DIREITO - UGF',
#  'SENAC, atraso com diploma e inrregulariedade com prazo',
#  'Descaso com o aluno',
#  'orientacao',
#  'Denuncia',
#  'Aulas de EAD',
#  'Registro de Pedagoga',
#  'mestrado',
#  'REclamacao sobre a Faculdade ENIAC',
#  'Vale tranporte para instituicao',
#  'descredenciamento das universidades gama filho e Univercidade e diplomacao',
#  'pergunta',
#  'Duvida sobre o diploma da UniverCidade - curso concluido em 2011',
#  'Estagio na IES',
#  'FIES',
#  'Autorizacao MEC',
#  'licenca a maternidade',
#  'Historico Escolar',
#  'Pendencia na resposta reclamacao faculdade',
#  'direito do LUNO',
#  'MINHA ESCOLA NAO EXISTE MAIS COMO PEGO O HISTORIO ESCOLAR?',
#  'Bolsa de iniciacao cientifica CNPq',
#  'Mestrado para professores em exercicio',
#  'VINCULO PROFISSIONAL no SIMEC  -  SIS-MEDIO',
#  'como abrir uma escola de Ingles autorizada pelo MEC',
#  'transferencia',
#  'Informacao de endereco e fone de faculdade',
#  'DIPLOMA UNIVERSIDADE GAMA FILHO',
#  'DENUNCIA',
#  'certificacao do curso de prevencao antidrogas UNB',
#  'Reclamacao- Universidade Norte do Parana - Unopar',
#  'DESCASO COM UM PROFESSOR',
#  'HISTORICO ESCOLAR',
#  'Transferencia Assistida - Universidade Estacio de Sa / Gama Filho ',
#  'duvidas',
#  'Informacoes',
#  'provas',
#  'Erro de enceramento fies',
#  'educacao intantil',
#  'prefeitura nao permite estagio',
#  'educacao de qualidade',
#  'historico escolar',
#  'insatisfacao cm o transporte escolar d municipio de Flores de Goias',
#  'FIES',
#  'carimbo historico escolar',
#  'Numero de alunos por sala de aula em Univercidade Privada',
#  'ALTERACAO DE NOME (PATERNIDADE)',
#  'Validacao de diploma universitario de outro pais',
#  'denuncia',
#  'Reajuste abusivo de mensalidade ',
#  'Pedido de Ajuda Urgente',
#  'Ciencia sem Fronteiras',
#  'fiz curso de matematica na Unitins e nao consigo receber o diploma',
#  'Historico escolar da Universidade Sao Marcos',
#  'DIPLOMA',
#  'Univercidade Gama Filho',
#  'Orientacao',
#  'FACULDADE PESSIMA',
#  'Banda de Fanfarra',
#  'materiais didaticos pedagogicos',
#  'Confirmar a se a escola e regulamentada',
#  'PDE',
#  'Reclamacao da faculdade UNIESP',
#  'SOBRE MINHA INSCRICAO NO ENADE',
#  'Bolsa de estudos no exterior ',
#  'Diploma ',
#  'sugestao',
#  'Pais divorciados',
#  'PRECISO DO MEU CONTEUDO PROGRAMA TICO DE GRADUACAO',
#  'cadastramento de escola',
#  'bolsa permanencia MEC',
#  'reclamacao da instituicao de ensino',
#  'Duvidas',
#  'Denuncia',
#  'historico escolar',
#  'GREVE UNIVER-CIDADE',
#  'A QUEM POSSA INTERESSAR (3)',
#  'segunda via do diploma',
#  'Informacao',
#  'Escola Municipal fechada/desativada/extinta',
#  'historico escolar',
#  'informacao pagamento do fies ',
#  'Graduacao por Modulo',
#  ' reclamacao iftm',
#  'denuncia ',
#  'Gratificacao AEIs ( Agente de Educacao Infantil)',
#  'fies- analise de oficio',
#  'RECLAMACAO',
#  'dependencia em materia',
#  'Como fazer reclamacao de Instituicao de Ensino junto ao MEC?',
#  'Matricula em duas instituicoes de ensino superior publico',
#  'Reclamacao de Documentacao',
#  'CURSO OPCIONAL/ CONTEUDOS',
#  'Duvida sobre prova substitutiva.',
#  'Grade Incompleta das Disciplinas',
#  'fiscalizacao',
#  'prouni',
#  'VAGAS REMANESCENTES',
#  'Historico Escolar',
#  'Historico Escolar',
#  'Reclamacao ',
#  'Documentacao Gama FIlho',
#  'informacao',
#  'Historico ',
#  'FECHAMENTO DA UNIVERCIDADE ',
#  'Denuncia',
#  'Taxa de renovacao de matricula e taxa de material',
#  'Historico Escolar',
#  'Normal Superior',
#  'Denuncia - Urgente',
#  'Esclarecimentos',
#  'ESTAGIO',
#  'quero fazer minha inscicao no sisutec porfavor',
#  'Validacao diploma internacional',
#  'Transferencia de bolsa e trancamento da mesma ',
#  'informacao',
#  'Certificacao do Enem',
#  'Cobranca de estagio como disciplina',
#  'Escola onde concluira o Ensino Medio',
#  'Emissao de Diploma de faculdade descredenciada ( Univercidade)',
#  'Denuncia ',
#  'fies',
#  'aulas de arte',
#  'transferencia Prouni',
#  'Aba que nao aparece do Mais Educacao dentro do PDDE - Interativo',
#  'Pessima orientacao para TCC e omissao da Instituicao.',
#  'carteira do estudante',
#  'Convalidacao de semestre',
#  'denuncia faculdade ',
#  'duvidas provas objetiva e disertiva',
#  'Historico escolar',
#  'DOCUMENTOS ',
#  'Transferencia',
#  'verificar se a escola do meu filho registrou ele na secretaria da educacao',
#  'Faculdade de medicina paga pelo governo para trabalhar para o sus',
#  'emissao de certificados de conclusao de cursos',
#  'bolsa prouni',
#  'Remebolso da Educa Mais Brasil',
#  'FIES',
#  'diploma',
#  'historico escolar / ficha 18 e 19',
#  'Faculdade que Fechou',
#  'instituicoes credenciadas',
#  'Falta de transparencia da instituicao',
#  'CURSO TTI ESCOLA BORBA GATO SANTO AMARO SP',
#  'diploma 2o grau',
#  'esclarecimentos',
#  'faculdade estacio de sa',
#  'relacao das universidades efaculdades do curso de graduacao em ed fisica',
#  'Pedido de certificado da Gama Filho',
#  'magisterio',
#  'pronatec',
#  'estagio',
#  'Diploma',
#  'PEDIDO',
#  'Recuperacao de Documentos ',
#  'Desbloqueio do programa saude nas escolas.',
#  'Homologacao e Convalidacao de Titulos no Exterior',
#  'ACESSO BIBLIOTECA FACULDADE PARTICULAR',
#  'Instituiicao de Ensino ',
#  'ESCLARECIMENTO ',
#  'autismo',
#  'Certificado de conclusao de serie',
#  'Diploma UGF',
#  'problemas em pegar certificado em faculdade privada',
#  'EDUCACAO A DISTANCIA - UNOPAR',
#  'Livros Didaticos',
#  'Como Obter a Segunda Via do Historico Escolar?',
#  'Reconhecimento das ementas ',
#  'custeio da faculdade de medicina pelo governo federal.',
#  'Diploma da UGF',
#  'a faculdade me impossibilitou de continuar o meu curso pelo fies preciso mudar de curso',
#  'Diploma de universidade que fechou',
#  'dispensa de disciplina na faculdade',
#  'FALTA DE PROFESSOR',
#  'Numero excessivo de alunos por sala.',
#  'Projeto Social',
#  'Quero, Almejo reclamar da conduta onde faco 02 semestre de Faculdade',
#  'Falha no site da Faculdade Sumare para concluir licao oline.',
#  'Reclamacao a instituicao UNIFACS.',
#  'Indignacao',
#  'Tirar reservista de emergencia',
#  'colacao de grau ',
#  'Duvida',
#  'diploma da univercidadedacidade rj',
#  'DIPLOMA',
#  'irregularidades em faculdade',
#  'Falta de documento',
#  'sobre a prova do enem para quem ta estudado a distancia para concluir o 2 grau',
#  'Ensino Fundamental em escolas municipais',
#  'PUBLICACAO DOS PCNS',
#  'como solicitar diploma em graduacao, pois a faculdade onde estudei fechou',
#  'Mostra Cultural de Aviacao',
#  'Academico',
#  ' reclamacao iftm',
#  'reclamacao',
#  'Orientacao ',
#  'carteira do professor',
#  'PERDA BOLSA PROUNI',
#  'Diploma',
#  'providencias, colacao de grau-diploma da EAD UNITINS',
#  'Grade curricular',
#  'Devolucao da taxa de inscricao do Enem',
#  'denuncia',
#  'duvida sobre escola extinta',
#  'sobre o curso  tec de informaticfa pelo pronatec',
#  'Conteudo programatico faculdade',
#  'reclamacao de faculdade',
#  'Certificado de Curso de Pos Graduacao',
#  'educacao',
#  'Quero cadastrar minha escola no enem',
#  'acervo  academico da Universidade Gama  Filho',
#  'Creches inclusivas',
#  'livros',
#  'INFORMACAO',
#  'telefone fixo',
#  'Colacao de grau',
#  'Diplomacao UNIVERCIDADE E GAMA FILHO',
#  'Tempo de entrega de diploma',
#  'Aplicacao TOEFL',
#  'Taxas',
#  'Historico escolar',
#  'Atestado de Obito/ Prova Substitutiva',
#  'Bolsa Permanencia',
#  'Segunda via de Diploma',
#  'denuncia',
#  'CURSO SUPERIOR',
#  'greve na escola ',
#  'um terco da carga horaria para planejamento do professor',
#  'greve sem previsao de terminar IFPA (Campus Industrial Maraba)',
#  'Alojamento',
#  'Denuncia ',
#  'concurso publico ',
#  'Diploma nao entregue pela faculdade Pitagoras BH.MG',
#  'internato alunos em faculdades de medicina no brasil',
#  'INFORMACAO',
#  'reclamacao de escola de ensino infantil',
#  'solicitacao de materiais escolares em excesso',
#  'Elogio Ao Pronatec',
#  'DIPLOMA UNIVERSIDADE SAO MARCOS',
#  'Diploma nivel superior',
#  'Ajuda de custo',
#  'Registro de Faculdade',
#  'Recuperacao de Certificado de Conclusao',
#  'bolsa formacao',
#  'Piso Nacional Professores',
#  'proemi',
#  'PROUNI',
#  'Duvidas supletivo',
#  'Duvida',
#  'Cancelar matricula na Unopar  que fiz pelo Prouni 2014.1',
#  'adaptacoes de materias',
#  'Reclamacao sobre a Universidade Nove de Julho Uninove',
#  'calendario escolar',
#  'fiscalizacao',
#  'Carteira funcional de registro em orgao do MEC- registro de diplomas.',
#  'Aulas em campus diferentes da Faculdade',
#  'Cotas de racas sem sentido',
#  'Educacao infantil ser obrigada ou nao a imposicao do ensino religioso',
#  'Pos-graduacao ',
#  'prorrogacao arbitraria de ferias escolares de autistas',
#  'Numero de alunos por sala de aula em Univercidade Privada',
#  'atraso',
#  'Incluir nome na folha do Diario Oficial',
#  'constituicao',
#  'ingresso na faculdade pelo programa prouni',
#  'Duvida sobre o meu curso',
#  'segunda via de diploma',
#  'reclamacao',
#  'ubc ead',
#  'Transferencia',
#  'mensalidade escolar',
#  'notas',
#  'reclamacoes  condicoes de  sala  de  aula ',
#  'NAO ESTOU CONSEGUINDO PASSAR DO 3 PASSO',
#  'CURSO SUPERIOR',
#  'quero trabalhar como professor do PRONATEC',
#  'notas e faltas irregulares no sistema pitagoras pronatec',
#  'Consulta sobre exigencia de novo vestibular - SENAC',
#  'Denuncia',
#  'BOLETO',
#  'DESISTENCIA DE MATRICULA',
#  'DOCUMENTOS RELATIVO A FACULDADE QUE MUDOU DE BAIRRO.',
#  'Retirada da 1a via de Diploma da instituicao que decretou falencia ',
#  'Informacao',
#  'material escolar na escola particular',
#  'Diploma USM',
#  'TCC',
#  'GREVE DE SERVIDORES DO MUNICIPIO DE JOINVILLE E REPOSICAO DE DIAS LETIVOS',
#  'BOLSA DE ESTUDO',
#  'Livro Didatico',
#  'Impedimento de Participacao Prouni',
#  'Revalidacao de diploma e trabalho no exterior',
#  'FIES',
#  'Descredenciamento da UniverCidade ',
#  'Solicitacao de Speedy na escola - Banda Larga',
#  'Relamacao da Faculdade Estacio de Boa Vista-RR',
#  'Educacao Infantil',
#  'MODULO E.I. MANUTENCAO',
#  'calendario escolar',
#  'carimbo do mec',
#  'pagamento de recuperacao em escola particular',
#  'Gama Filho - Reingresso Estacio de Sa',
#  'informacao sobre diploma a nivel superior',
#  'Federalizcao Gama Filho e Univercidade',
#  'historico escolar',
#  'cancelamento do fies',
#  'solicitacao de livros',
#  'Estacio de Sa_descaso com alunos',
#  'Orientacao ',
#  'certificado de escolaridade',
#  'SISUTEC',
#  'Bolsa Permanencia',
#  'Reclamacao sobre a instituicao FMU',
#  'RECLAMACAO',
#  'Problemas com a faculdade',
#  'Historico Escolar',
#  'pergunta',
#  ' escola cadastrada no MEC',
#  'bolsa-auxilio',
#  'Mudanca de turno no curso',
#  'Descredenciamento da Gama Filho',
#  'Relatorio de visita.',
#  'Impedimento de Matricula e negacao de transferencia da Instituicao de ensino',
#  'Coalcao de Grau',
#  'telefone fixo',
#  'ENADE',
#  'informacoes',
#  'Nao entrega diploma de graduacao',
#  'Revalidacao de diploma de doutorado obtido no Brasil (UFPB)',
#  'Informacao',
#  'mudanca de curso',
#  'CERTIFICADO DO CURSO SEGURANCA DO TRABALHO EM ESCOLA TECNICA A COOLMINAS',
#  'computadores quebrados na minha escola',
#  'Historico escolar',
#  'NOTA ENEM 2008',
#  'provas do enem',
#  'Estou impossibilitada de ganhar bolsa prouni',
#  'Cobranca de taxas',
#  'Universidade Gama Filho ',
#  'GOSTARIA DE CANCELAR MINHA BOLSA PROUNI MAS  A FACULDADE FALIU E O MEC NAO ME DA RESPOSTAS ',
#  'Notas do Enem',
#  'segunda via certificado do 2o grau',
#  'DIPLOMA ',
#  'isencao impostos',
#  'Estacio de Sa_descaso com alunos',
#  'reclamacao',
#  'Reclamacao Pronatec',
#  'prouni',
#  'Denuncia de irregularidades em faculdade',
#  'verificacao historico escolar',
#  'dengue hemorragica/matricula na faculdade ate 06/06/2014',
#  'Escola Particular Legal',
#  'prefeitura',
#  'Diploma Superior - Curso Direito',
#  'Duvidas sobre o ENEM',
#  'Erro no cadastro do Enen 2014',
#  'Informacoes sobre o ENSEJA',
#  'REGULARIDADE DE UMA ESCOLA',
#  'mudanca de turno',
#  'Negado a inclusao de aluno com deficiencia no curso EJA',
#  'autenticar documentos',
#  'Problema Com Instituicao',
#  'transferencia assistida',
#  'INVESTIGACAO DA ESCOLA BORBA GATO SAP PAULO -EM SANTO AMARO A RESPEITO DO CURSO  T T I',
#  'Solicitacao de Diploma',
#  'Validacao de Historico Escolar - Ensino Medio',
#  'Convalidacao de semestre',
#  'Sistec/Pronatec',
#  'Certificado de Pos Graduacao',
#  'Reclamacao',
#  'exclusao de colacao de grau na faculdade',
#  'Ensino Superior Privado - Diploma',
#  'Revalidacao do diploma obtido no Brasil no Chile',
#  'autenticar diploma e historico',
#  'Reclamacao a UNIVERSO Recife',
#  'Faculdades Aprovadas',
#  'Procedimento para estudar na Bolivia',
#  'falta de livros',
#  'Instituicao de Ensino',
#  'Reclamacao do metodo de avaliacao da EAD UNINTER',
#  'Inscricao enem 2015',
#  'Carteirinha de Professor ',
#  'Bolsas PROUNI',
#  'reclamacaos bolsa UNIEDU',
#  'RECLAMACAO FACULDADE CRUZEIRO DO SUL (EAD)',
#  'Oportunidade para estudar!!!',
#  'Extincao de escolas rural municipal',
#  'Carimbo do MEC',
#  'DOCUMENTOS PENDENTES',
#  'Sobre  disciplinas quantas o aluno pode ficar reprovado no periodo do curso. Fies',
#  'Prouni',
#  'Tirar Duvidas',
#  'IFCE ( Instituto Federal de Educacao, Ciencia e Tecnologia do Ceara) Maracanau',
#  'Fmu',
#  'educacao e ensino ',
#  'CFAQ-MAM/MOC',
#  'DIPLOMA',
#  'Falta de livros nas escolas da rede Publica de Itatiba SP',
#  'Perda de Bolsa do Prouni',
#  'Direito sobre o meu diploma superior',
#  'reclamacao',
#  'segunda faculdade',
#  'CURSO SUPERIOR',
#  'como obter autorizacao para abertura de uma Escola Tecnica de Radiologia',
#  'escola na copa ',
#  'Proposta de Criacao de Laboratorio de Humanas',
#  'Conhecimento das regras do MEC na aplicacao da prova no ensino superior',
#  'Prouni',
#  'Cancelamento do PROUNI',
#  'segunda via do diploma',
#  'Processo Administrativo',
#  'Mais Educacao parajovens de 15 a 17 anos',
#  'registro de faculdade e cursos on-laine',
#  'PROUNI- DOCUMENTOS EXIGIDOS PARA A ADESAO DA BOLSA',
#  'CURSO SUPERIOR',
#  'diploma',
#  'Numero de alunos por sala na educacao infantil',
#  'REPROVACAO ESCOLAR',
#  'PEDIDO DE 2* VIA DO HISTORICO ESCOLAR DE 2* GRAU',
#  'UniverCidade - diploma nao expedido',
#  'MEDIA ESCOLAR ',
#  'Pronatec',
#  'Segunda via de diploma e historico escolar de escola ja extinta',
#  'programa mais educacao',
#  'Expedicao de Historico Escolar',
#  ' reclamacao iftm',
#  'CADASTRAMENTO DE ALUNOS NA REDE PUBLICA E PARTICULAR DE ENSINO',
#  'Universidade Baneirante de SP - Anhanguera',
#  'Graduacao',
#  'univercidade/gama filho',
#  'Conhecimento das regras do MEC na aplicacao da prova no ensino superior',
#  'Denuncia',
#  'Obtencao do CREA',
#  'Auxilio estudantil',
#  'Contatos de Supletivos a Distancia e Presencial Registrados no MEC.',
#  'PDDE',
#  'Reclamacao ',
#  'Certificado de Conclusao Curso Ciencias Contabeis Univ Gama Filho',
#  'Informacao.',
#  'Fasipe',
#  'Validacao de diploma no exterior.',
#  'UNIVERCIDADE',
#  'Fechamento da Universidade Gama Filho',
#  'INAF',
#  'aditamento',
#  'Tranferencia',
#  'Diploma Faculdades Anhanguera - Campinas',
#  'APROVEITAMENTO DE MATERIAS',
#  'Descredenciamento de universidade',
#  'Certificado de diploma',
#  'Bolsa do programa Escola da Terra',
#  '+EDUCACAO',
#  'Duvida sobre Retribuicao por Titulacao para professores Temporarios',
#  'reclamacao',
#  'Problemas na Faculdade',
#  'ILEGALIDADE NA ESCOLHA DE DIRETOR DE ESCOLA PUBLICA',
#  'saber se uma escola e cadastrada no MEC',
#  'Duvidas sobre a Faculdade UNIESP Sorocaba',
#  'Disponibilizacao - Port. 584/97',
#  'Irregularidades na Universidade Estacio de Sa Sulacap',
#  'Bolsa Permanencia',
#  'faculdade',
#  'Pessoas PC ainda tem direitos ?',
#  'Esclarecimentos',
#  'Faculdade Anhanguera',
#  'Acerca de Irregularidades',
#  'Diploma nao expedido por Instituicao',
#  'graduacao',
#  'Notas do Mec',
#  'COMPROVANTE DE MATRICULA',
#  'cursos Pronatec',
#  'Lotacao em sala de aula',
#  'livros didaticos',
#  'Falta do plano de ensino para materia de graduacao tecnologia em sistema de gestao da qualidade',
#  'quero fazer minha inscicao no sisutec porfavor',
#  'Ingles no ensino fundamental',
#  ' Edicao de obra literaria',
#  'URGENTE',
#  'obtencao de diploma da Universidade Gama Filho',
#  'reclamacao sobre a nao disponibilidade de livros didaticos para todos os alunos.',
#  'hora-aula segundo a lei do piso 11738',
#  'Quantidade de alunos nas Universidades Privadas no Estado de Sao Paulo',
#  'Envio de KIT',
#  'Localizacao de Instituicao de ensino',
#  'DUVIDA',
#  'Diploma pendente',
#  'Bolsa integral',
#  'Denuncia de instituicao de Ensino Superior',
#  'HISTORICO ESCOLAR',
#  'fazer um denuncia contra a escola caminho do aprender',
#  'Resultado dos aprovados nas eliminacoes de materia "enceja 2013"  ',
#  'Comemoracao da Escola Santa Lucia Filippini',
#  'prorrogacao de ferias escolares de autistas',
#  'Demanda',
#  'Nova E.J.A',
#  'Profissao de professor',
#  'Corte de aulas',
#  'Ciencia sem Fronteiras',
#  'Pedido de Informacao',
#  'CANCELAMENTO DA ASSINATURA DIGITAL',
#  'Regulamentacao de Escola Particular dada pelo MEC',
#  'SALARIO  MATERNIDADE',
#  'graduacao em educacao especial',
#  'Cobranca indevida universidade Presbiteriana Mackenzie',
#  'Diploma de Ensino Superior',
#  'Falta de Livro Didatico no colegio Henrique Lage (FAETEC) ',
#  'Dificuldades em fechar o censo',
#  'solicitacao de livros',
#  'Taxas',
#  'Falta de professores ',
#  'escola profissionalizante',
#  'colacao de grau e certificado',
#  'diploma validado pelo MEC.',
#  'informacoes sobre o Instituto Nacional de Educacao Profissional',
#  'Minha filha e o Enem',
#  'Dobra de Carga Horaria',
#  'problema na inscricao do ENADE',
#  'consultar escola de ensino medio a distancia',
#  'descaso',
#  'falta de livros',
#  'profletras',
#  'Sobre  disciplinas quantas o aluno pode ficar reprovado no periodo do curso. Fies',
#  'Apressamento de certificado de conclusao de curso superior',
#  'Sala de recursos multifuncionais',
#  'Continuacao da msg anterior sobre o PCMSE',
#  'numerode alunos por Sala de Aula',
#  'suspensao sobre FIES',
#  'Reclamacao erro de debito junto a IES',
#  'site pronatec nao funcionando',
#  'nao consigo o estorico do colegio ',
#  '  fiz o finaciamento pelo fies mas devido  transferencia de trabalho e mudanca de cidade nao fui',
#  'RECLAMACAO',
#  'Liberacao de documentacao',
#  'como conseguir documentacao de uma universidade que encerrou as atividades',
#  'telefone fixo',
#  'educacao',
#  'Diploma',
#  'Referente ao pagamento que tem 04 bloqueados  e gostaria de saber quando vou receber ',
#  'prestacao de servico',
#  'denuncia',
#  'faculdade Gama filho',
#  'Descredenciamento  de universidade',
#  'Reclamacao',
#  'Atestado de Obito/ Prova Substitutiva',
#  'solicitacao historico e diploma',
#  'Reajuste abusivo de mensalidade',
#  'mensalidades',
#  'Cancelamento de matricula',
#  'transferencia assistida aluna da univercidade',
#  'Erro no cadastro do Enen 2014',
#  'Denuncia Alfacastelo/Uniesp',
#  'Codigo Mec',
#  'Informacoes',
#  'informacao sobre conduta de universidade',
#  'SISMEC X PDE -',
#  'Quadra de esportes',
#  'Reclamacao',
#  'Direito do estudante',
#  'Implantacao de um supletivo dentro da empresa',
#  'Prouni - Falta de comunicacao da UNIFRAN',
#  'emissao diploma',
#  'Universidade Sao Marcos',
#  'fraude no concurso instituto federal farroupilha - rio grande sul',
#  'URGENTE',
#  'A QUEM POSSA INTERESSAR (2)',
#  'Reclamacao de faculdade',
#  'ensino a distancia e crianca de seis anos sem estudar por falta de vaga!',
#  'Denuncia Universidade',
#  'TRANCAR FACULDADE',
#  'Reclamacao sobre ProUni',
#  'CURSO SUPERIOR',
#  ' reclamacao iftm',
#  'Informacao sobre um colegio',
#  'enem2014',
#  'Enade',
#  'ENADE',
#  'BOLSISTA DO PROUNI',
#  'registro de escola',
#  'sugestao -urgente ',
#  'informacao escolar',
#  'Faculdade Privada',
#  'emissao de certificados de conclusao de cursos',
#  'colegio autorizado',
#  'Sobre professor',
#  'pnaic',
#  'Transferencia assistida',
#  'Orientacao',
#  'Livros nivel superior',
#  'A nao entrega de diploma da Graduacao',
#  'reclamacao',
#  'duvida',
#  'Insatisfacao com a Universidade Nove de Julho',
#  'Aluna da UniverCidade',
#  'Irregularidades no CVT de Barra Mansa',
#  'INFORMACAO SOBRE DIREITOS EM FACULDADE',
#  'Nome escrito erroneamente',
#  'Discliminacao com o cliente, desde 2008 nao resolvem o problema, ',
#  'indignacao',
#  'Valor abusivo da DEPE',
#  'Consulta a lista de inscritos no ENADE',
#  'Diploma',
#  'Trabalho social',
#  'Historico Escolar',
#  'Bibliotecas das escolas estaduais em Alagoas',
#  'Irregularidades das Universidades ',
#  'Cancelamento da bolsa do Prouni para dar baixa',
#  '2a Via de Diploma Univercidade',
#  'informacoes gerais',
#  'BRASIL ALFABETIZADO E PEJA',
#  'solicitacao de reclamacao MEC',
#  'INSCRICAO INGLES SEM FRONTEIRAS',
#  'chamada para graduacao em pedagogia na uff',
#  'Cancelamento do fies nao solicitado',
#  'Duvidas em alteracao do cadastro (escola)',
#  'transferencia do fies',
#  'cargo de diretor',
#  'Pessima Administracao UVA',
#  'Forma de ingresso em Instituicao Publica de Ensino Superior (Reingresso)',
#  'fiz a prova do enm em 2011 porem perdi os documentos...',
#  'QUERO O MEU DIPLOMA',
#  'Valor hora Aula Professor PRONATEC',
#  'Faculdade nao atualiza os pagamentos efetuados e eu nao consigo fazer a matricula',
#  'sorteada para ganhar um beneficio de 200 reais em dinheiro',
#  'Grade curricular',
#  'Professor',
#  'Declaracao de escolaridade',
#  'Retirada de 1a via de Diploma na Universidade ',
#  'Aprovada',
#  'Solicitacao Diploma Universidade Gama Filho',
#  'Denuncia na Faculdede',
#  'Nao achei nada sobre a biologia',
#  'recolhimento de diploma de faculdade que encerrou atividades',
#  'Valores de documentos  cobrados pelas instituicoes.',
#  'Apenas uma chance!',
#  'Sala de Recursos Multifuncionais',
#  'Certificado de Conclusao Curso de Saude da Familia - UGF',
#  'Falta de aula pratica',
#  'Reclamacao Aplicacao prova EBSERH ANA BEZERRA/RN',
#  'bolsa de estudo',
#  'Diploma Centro Universitario da Cidade',
#  'Diploma',
#  'Solicitacao midias mecdaisy',
#  'Instituiicao de Ensino ',
#  'Sobre a ajuda financeira do Pronatec',
#  'Prouni',
#  'Orientacao',
#  'Informacao',
#  'Pedido de diploma de Curso de Complementacao',
#  'informacoes',
#  'material para alfabetizacao crianca com implante coclear',
#  'REGULARIDADE DE UMA ESCOLA',
#  'aditamento',
#  'fies',
#  'TOEFL-INGLES SEM FRONTEIRA',
#  'Programa  Mais Educacao',
#  'enem 2013',
#  'Curso para capacitacao de cuidadores de animais - Zoologico',
#  'historico escolar',
#  'DP',
#  'Faculdade Uniesp',
#  'DIPLOMA - ME AJUDEM POR FAVOR APENAS COM UMA INFORMACAO',
#  'prorrogacao arbitraria de ferias escolares de autistas',
#  'Solicitacao de endereco',
#  'prorrogacao de ferias escolares de autistas',
#  'Curso',
#  'Denuncia e exclarecimentos',
#  'Curo profissionalizante',
#  'Curso TECNICO INFORMATICA realizado em UNIVERISDADE',
#  'Livros Didaticos',
#  'Denuncia de irregularidade',
#  'calendario escolar',
#  'Pronatec',
#  'Registro de curso',
#  'Nao cumprimento legal da lei de Universidade',
#  'porfavor preciso mim inscrever. nao consigo fizum curso e cancelei por motivo de trabalho, mim ajude',
#  'Diploma UniverCidade',
#  'Retirar o Historico Escolar da Escola de Origem',
#  'Compromisso com os alunos',
#  'prestacao de contas',
#  'Historico e documentos de Graduacao do Ensino superior',
#  'denuncia',
#  'Saber a nota da univirsidade e do curso.',
#  'gostaria saber pronatec tecnicologistica tem alguma ajuda',
#  'Descredenciamento da Gama Filho',
#  'secretario escolar',
#  'consulta sobre direito a trancamento de matriculo- curso superior',
#  'Bolsa de estudos',
#  'informacao sobre validacao de diplomas  ',
#  'Faculdade se nega a entregar historico escolar por inadimplencia',
#  'Duvidas... ',
#  'Referencia sobre a Escola',
#  'faculdade (funorte)',
#  'Documento preso na faculdade',
#  'Informacao',
#  ' PRONATEC: DENUNCIA CONTRA O SENAI DE SANTA CRUZ, MUNICIPIO DO RIO DE JANEIRO',
#  'Reclamacao',
#  'Ilegalidades da instituicao estacio de sa',
#  'transferencia de Faculdade',
#  'Cadastro no SISMEC',
#  'FISCALIZACAO DE CURSO EM UNIVERSIDADE',
#  'Informacao sobre Enade',
#  'RESSARCIMENTO FIES ',
#  'Auditoria',
#  'historico escolar Universidade Gama Filho',
#  'Bolsa de estudo',
#  'Relatorio de visita.',
#  'financiamento',
#  'Duvida sobre acesso a documentacao estudantil',
#  'pronatec',
#  'Duvida',
#  'Mudanca de Nota de Aluno',
#  'Duvidas sobre atuacao de uma Faculdade',
#  'Reclamacao referente a Faculdade Estacio de Sa',
#  'Fies',
#  'Financiamento',
#  'a faculdade fabra me excluiu de fazer a prova final',
#  'historico escolar de curso de pos graduacao',
#  'Preciso seu ajuda',
#  'Revalidacao de diploma no Brasil expedido por Universidade estarngeira',
#  'MATRICULA DE ALUNO/VINCULACAO',
#  'EDUCACAO',
#  'pronatec',
#  'Transferencia escolar',
#  'faculdade  sumare',
#  'DESISTENCIA DE MATRICULA',
#  'DIPLOMA UNIVERSITARIO',
#  'abuso de autorida e molesta universitaria',
#  'Faculdade que Fechou',
#  'Dificuldade de conclusao pos graduacao - Universidade Gama Filho',
#  'Analise dos metodos de ensino da Universidade Anhanguera',
#  'residencia multiprofissional em PSF',
#  'DIPLOMA UNIVER CIDADE',
#  'UniverCidade - Historico Escolar',
#  'demanda nao respondida',
#  'Reprovacao de Disciplina com notas realizadas e nao postadas',
#  ' Tempo de magiterio descartado!',
#  'Taxa',
#  'denuncia de nao cumprimento de carga horaria',
#  'Reembolso de mensalidades',
#  'emissao de diploma',
#  'Pedido de ajuda para que eu possa trabalhar',
#  'Reembolso escolar',
#  'Informacao',
#  'solicitacao de livros',
#  'Pedido de Informacao - Reclamacao',
#  'legislacao sobre carga horaria',
#  'Bolsas Estudantis ',
#  'Mudanca no acesso a legislacao',
#  'cobertura em quadra esportiva de escola particular',
#  'Atividades Complementares - DUVIDA',
#  'Cadastro Senso ',
#  'EMISSAO DE DIPLOMA OU DECLARACAO DE CONCLUSAO DO NIVEL SUPERIOR',
#  'Educaca',
#  'Diploma da UniverCidade',
#  'DIPLOMA',
#  'Inscricao do Enem ',
#  'DP - Fac Uniesp  Por Motivo de Morte ( Urgente)',
#  'aula on line',
#  'RECLAMACAO SOBRE DIPLOMA ',
#  'reclamacoes  condicoes de  sala  de  aula ',
#  'EPEC-AVM',
#  'Alunos do municipio de Sao Sebastiao do Alto',
#  'abuso de autorida e molesta universitaria',
#  'ajuda',
#  'escola funcionando sem documentos ',
#  'diploma',
#  'DIPLOMA ',
#  'TRANSPORTE ESCOLAR - UTILIZACAO.',
#  'RECURSO PDDE ',
#  'Diploma',
#  'sobre  cadastro no educa mais brasil ',
#  'Faculdade',
#  'Descontentamento com uma instituicao de ensino',
#  'videos  "mao na forma"',
#  'Inclusao de Escola no Recursos do Fundeb',
#  'OI',
#  'Mestrado na area de Educacao',
#  'E.M.E.I PADRE SIMON IRREGULARIDADES GRAVISSIMAS',
#  'COLEGIO INTERACAO ITUPEVA  -  ESCOLA PARTICULAR',
#  'certificado de conclusao faculdade paulo eiro 1989',
#  'prefeitura',
#  'Estagio Supervisionado',
#  'Diploma',
#  'preciso de uma  declaracao',
#  "Informacoes sobre como solicitar recursos para a adequacao de banheiros para PNE's",
#  'BENEFICIOS',
#  'DUVIDAS SOBRE RECLAMACOES',
#  'Preciso saber aonde esta o meu documento .... de uma escola que fechou... urgente',
#  'cancelamento da matricula ',
#  'Denuncia',
#  'reconhecimento de uma escola ',
#  'transferencia do fies',
#  'Auxilio estudantil Pronatec',
#  'Reprovacao por faltas...',
#  'O meu portal do Fies, gerou dados errados em relacao a mim.',
#  'UNIVERSIDADE GAMA FILHO',
#  'livros escolares',
#  'duvida',
#  'retencao retencao historico escolar, do ensino superior',
#  'Diploma Gama Filho - RJ',
#  'bolsas',
#  'Carteira de Professor',
#  'Mais Educacao',
#  ...]

# %%
# Analisando resultado
import numpy as np
from sklearn import metrics

labels = km.labels_
metrics.silhouette_score(X, labels)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-003bf780436c> in <module>()
#       4
#       5 labels = km.labels_
# ----> 6 metrics.silhouette_score(X, labels)
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/cluster/unsupervised.pyc in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#      91         else:
#      92             X, labels = X[indices], labels[indices]
# ---> 93     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#      94
#      95
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/cluster/unsupervised.pyc in silhouette_samples(X, labels, metric, **kwds)
#     152
#     153     """
# --> 154     distances = pairwise_distances(X, metric=metric, **kwds)
#     155     n = labels.shape[0]
#     156     A = np.array([_intra_cluster_distance(distances[i], labels, i)
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in pairwise_distances(X, Y, metric, n_jobs, **kwds)
#    1071         func = PAIRWISE_DISTANCE_FUNCTIONS[metric]
#    1072         if n_jobs == 1:
# -> 1073             return func(X, Y, **kwds)
#    1074         else:
#    1075             return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in euclidean_distances(X, Y, Y_norm_squared, squared)
#     212         XX = row_norms(X, squared=True)[:, np.newaxis]
#     213
# --> 214     distances = safe_sparse_dot(X, Y.T, dense_output=True)
#     215     distances *= -2
#     216     distances += XX
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/sklearn/utils/extmath.pyc in safe_sparse_dot(a, b, dense_output)
#     175         ret = a * b
#     176         if dense_output and hasattr(ret, "toarray"):
# --> 177             ret = ret.toarray()
#     178         return ret
#     179     else:
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/scipy/sparse/compressed.pyc in toarray(self, order, out)
#     938     def toarray(self, order=None, out=None):
#     939         """See the docstring for `spmatrix.toarray`."""
# --> 940         return self.tocoo(copy=False).toarray(order=order, out=out)
#     941
#     942     ##############################################################
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/scipy/sparse/coo.pyc in toarray(self, order, out)
#     278         M,N = self.shape
#     279         coo_todense(M, N, self.nnz, self.row, self.col, self.data,
# --> 280                     B.ravel('A'), fortran)
#     281         return B
#     282
#
# KeyboardInterrupt:

# %% [markdown]
# #### DBSCAN

# %%
from sklearn import cluster

dbscan = cluster.DBSCAN(eps=.2)

# %%
X_dense=X.todense()
dbscan.fit(X_dense)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-389-8ed6c6bfa48b> in <module>()
#       1 X_dense=X.todense()
# ----> 2 dbscan.fit(X_dense)
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/sklearn/cluster/dbscan_.pyc in fit(self, X)
#     246             Overwrite keywords from __init__.
#     247         """
# --> 248         clust = dbscan(X, **self.get_params())
#     249         self.core_sample_indices_, self.labels_ = clust
#     250         self.components_ = X[self.core_sample_indices_].copy()
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/sklearn/cluster/dbscan_.pyc in dbscan(X, eps, min_samples, metric, algorithm, leaf_size, p, random_state)
#     161                     else:
#     162                         n_neighborhood = neighbors_model.radius_neighbors(
# --> 163                             X[neighbor], eps, return_distance=False)[0]
#     164                     # check if its a core point as well
#     165                     if len(n_neighborhood) >= min_samples:
#
# /Users/wendell/anaconda/envs/python2/lib/python2.7/site-packages/sklearn/neighbors/base.pyc in radius_neighbors(self, X, radius, return_distance)
#     505         elif self._fit_method in ['ball_tree', 'kd_tree']:
#     506             results = self._tree.query_radius(X, radius,
# --> 507                                               return_distance=return_distance)
#     508             if return_distance:
#     509                 ind, dist = results
#
# KeyboardInterrupt:

# %% [markdown]
# #### Topics extraction with Non-Negative Matrix Factorization

# %%
from sklearn.decomposition import NMF

vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=10000, stop_words=stopwords_extended)
tfidf = vectorizer.fit_transform(mensagens_limpas)

nmf = NMF(n_components=10, random_state=1).fit(tfidf)
feature_names = vectorizer.get_feature_names()

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d:" % topic_idx)
    print(" ".join([feature_names[i]
                    for i in topic.argsort()[:-20 - 1:-1]]))
    print()
# Out:
# Topic #0:
# curs mec reconhec faculdad instituica tecnic graduaca pos distanc univers diplom sao oferec quer superior matricul ola credenc tard pronatec
# ()
# Topic #1:
# consig acess sit cont pagin encontr tent ajud ter result entrar dad consult onde aparec link informaco mud sistem ver
# ()
# Topic #2:
# inscrica enem pagament efetu fiz 2014 dia confirm bolet aparec realiz cpf consegu tent const pagu sit numer prov erro
# ()
# Topic #3:
# fies precis adit faculdad banc semestr consegu problem contrat financ ajud praz favor resolv cancel sistem urgent nom demand tent
# ()
# Topic #4:
# dia receb pod aguard dev desd poss ser trabalh inform respost agradec pag alun solicit fic mes proced tod algum
# ()
# Topic #5:
# fac numer quer via precis consegu obter benefici pis tir segund tard inss cpf carta perd consult empres nit noit
# ()
# Topic #6:
# senh email acess envi nov recuper esquec precis favor consegu login receb cpf solicit result lembr inval enem perd mand
# ()
# Topic #7:
# ensin medi certific conclusa conclu enem ano not diplom prov fundamental poss fiz precis instituica termin superior suplet colegi obter
# ()
# Topic #8:
# cadastr cpf tent email dad nom sistem erro program diz unic aparec alter mensag fiz federal errad receit realiz nov
# ()
# Topic #9:
# escol histor estud precis filh mec particul educaca fech public colegi alun onde professor livr sao matricul tecnic ano municipal
# ()

# %% [markdown]
# #### Other experiments
